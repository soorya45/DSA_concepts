# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class S:
    def __init__(self):
        self.head=None

    def dis(self):
        if self.head is None:
            print("empty")
        else:
            i=self.head
            while i:
                print(f"{i.data}--->",end="")
                i=i.next

    def atbeg(self,data):
        n=Node(data)
        n.next=self.head
        self.head=n

    def atend(self,data):
        n=Node(data)
        t=self.head
        if t.next != None:
            t=t.next
        t.next=n
    def at(self,data,pos):
        if self.head is None:
            print("empty")
        else:
            n=Node(data)
            t=self.head
            for i in range(1,pos-1):
                t=t.next
            n.next=t.next
            t.next=n




    def del_atb(self):
        if self.head is None:
            print("empty")
        else:
            t=self.head
            self.head=t.next
            print("deleted:",t.data)
            t=None

    def del_atend(self):
        if self.head is None:
            print("empty")
        else:
            temp=self.head.next
            t=self.head
            if temp.next != None:
                temp=temp.next
                t=t.next
            t.next=None
    def at_mend(self,pos):

        if self.head is None:
            print("empty")
        else:
            temp=self.head.next
            t=self.head
            for i in range(1,pos-1):
                temp=temp.next
                t=t.next
            t.next=temp.next
            temp.next=None







o=S()
while True:
    a=int(input("1\n2\n3\n4\n5\n6\n7\nyour choice"))
    if a==1:
        o.atbeg(int(input("data")))
    elif a==2:
        o.atend(int(input("data at end")))


    elif a==3:
        o.del_atb()
    elif a==4:
        o.del_atend()
    elif a==5:
        pos=int(input("postion"))
        data=int(input("data"))
        o.at(data,pos)
    elif a==6:
        o.at_mend(int(input("postion to delete")))



    elif a==7:
        o.dis()

    else:
        break
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice1
# data10
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice2
# data at end20
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice2
# data at end30
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice7
# 10--->20--->30--->1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice4
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice7
# 10--->20--->1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice3
# deleted: 10
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice7
# 20--->1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice1
# data10
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice1
# data40
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice7
# 40--->10--->20--->1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice5
# postion2
# data45
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice7
# 40--->45--->10--->20--->1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice6
# postion to delete2
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice7
# 40--->10--->20--->1
# 2
# 3
# 4
# 5
# 6
# 7
# your choice0

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class D:
    def __init__(self):
        self.head=None

    def dis(self):
        if self.head is None:
            print("empty")
        else:
            i=self.head
            while i:
                print(f"{i.data}--->",end="")
                i=i.next

    def atbeg(self,data):
        n=Node(data)
        n.next=self.head
        self.head=n

    def atend(self,data):
        n=Node(data)
        t=self.head
        if t.next != None:
            t=t.next
        t.next=n
        n.prev=t
    def at(self,data,pos):
        if self.head is None:
            print("empty")
        else:
            n=Node(data)
            t=self.head
            for i in range(1,pos-1):
                t=t.next
            n.prev=t
            n.next=t.next
            t.next.prex=n
            t.next=n




    def del_atb(self):
        if self.head is None:
            print("empty")
        else:
            t=self.head
            self.head=t.next
            print("deleted:",t.data)
            t=None

    def del_atend(self):
        if self.head is None:
            print("empty")
        else:
            temp=self.head.next
            t=self.head
            if temp.next != None:
                temp=temp.next
                t=t.next
            t.next=None
            temp.prev=None
    def at_mend(self,pos):

        if self.head is None:
            print("empty")
        else:
            temp=self.head.next
            t=self.head
            for i in range(1,pos-1):
                temp=temp.next
                t=t.next
            t.next=temp.next
            temp.next=None
            temp.prev=None







o=D()
while True:
    a=int(input("1\n2\n3\n4\n5\n6\n7\nyour choice"))
    if a==1:
        o.atbeg(int(input("data")))
    elif a==2:
        o.atend(int(input("data at end")))


    elif a==3:
        o.del_atb()
    elif a==4:
        o.del_atend()
    elif a==5:
        pos=int(input("postion"))
        data=int(input("data"))
        o.at(data,pos)
    elif a==6:
        o.at_mend(int(input("postion to delete")))



    elif a==7:
        o.dis()

    else:
        break
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# your choice1
# data10
# 1
# 2
# 3
# 4
# 5
# 6
# your choice2
# data at end20
# 1
# 2
# 3
# 4
# 5
# 6
# your choice2
# data at end30
# 1
# 2
# 3
# 4
# 5
# 6
# your choice7
# 10--->20--->30--->1
# 2
# 3
# 4
# 5
# 6
# your choice5
# postion1
# data25
# 1
# 2
# 3
# 4
# 5
# 6
# your choice7
# 10--->25--->20--->30--->1
# 2
# 3
# 4
# 5
# 6
# your choice6
# postion to delete2
# 1
# 2
# 3
# 4
# 5
# 6
# your choice7
# 10--->20--->30--->1
# 2
# 3
# 4
# 5
# 6
# your choice7
# 10--->20--->30--->1
# 2
# 3
# 4
# 5
# 6
# your choice7
# 10--->20--->30--->1
# 2
# 3
# 4
# 5
# 6
# your choice6
# postion to delete3
# 1
# 2
# 3
# 4
# 5
# 6
# your choice7
# 10--->20--->1
# 2
# 3
# 4
# 5
# 6
# your choice0

# %%
class Node:
  def __init__(self,data):
    self.prev = None
    self.data = data
    self.next = None

class Doubly_Linked_List:
  def __init__(self):
    self.head = None

  def display(self):
    if self.head is None:
      print("List is Empty")
    else:
      temp = self.head
      while temp:
        print(f"{temp.data} --> ",end ='')
        temp = temp.next

  def insert_beg(self,data):
    n = Node(data)
    n.next = self.head
    self.head = n

  def insert_end(self,data):
    n = Node(data)
    temp = self.head
    while temp.next is not None:
      temp = temp.next
    temp.next = n
    temp.next.prev = temp

  def insert_pos(self, pos, data):
    n = Node(data)
    temp = self.head
    for i in range(1,pos-1):
      temp = temp.next
    n.prev = temp
    n.next = temp.next
    temp.next.prev = n
    temp.next = n

  def del_beg(self):
    if self.head is None:
      print("List is Empty")

    else:
      temp = self.head
      self.head = temp.next
      temp.next = None

  def del_end(self):
    if self.head is None:
      print("List is Empty")

    else:
      temp = self.head.next
      t = self.head
      while temp.next is not None:
        temp = temp.next
        t = t.next
      t.next = None
      temp.prev = None

  def del_pos(self,pos):
    if self.head is None:
      print("List is Empty")

    else:
      temp = self.head.next
      before = self.head
      for i in range(1,pos-1):
        temp = temp.next
        before = before.next
      before.next = temp.next
      temp.prev = None
      temp.next = None

L = Doubly_Linked_List()
while True:
  print('''1.Insert at Beginning
2.Insert at Any position
3.Insert at End
4.Delete at Beginning
5.Delete at Any position
6.Delete at End
7.Display
8.Exit''')
  n = int(input("Enter the choice: "))
  if n == 1:
    data = int(input("Enter the data: "))
    L.insert_beg(data)
  elif n == 2:
    pos = int(input("Enter the position: "))
    data = int(input("Enter the data: "))
    L.insert_pos(pos,data)
  elif n == 3:
    data = int(input("Enter the data: "))
    L.insert_end(data)
  elif n == 4:
    L.del_beg()
  elif n == 5:
    pos = int(input("Enter the position: "))
    L.del_pos(pos)
  elif n == 6:
    L.del_end()
  elif n == 7:
    L.display()
    print("\n")
  elif n == 8:
    break
  else:
    print("Invalid Input")
# Out:
# 1.Insert at Beginning
# 2.Insert at Any position
# 3.Insert at End
# 4.Delete at Beginning
# 5.Delete at Any position
# 6.Delete at End
# 7.Display
# 8.Exit
# Enter the choice: 1
# Enter the data: 5
# 1.Insert at Beginning
# 2.Insert at Any position
# 3.Insert at End
# 4.Delete at Beginning
# 5.Delete at Any position
# 6.Delete at End
# 7.Display
# 8.Exit
# Enter the choice: 3
# Enter the data: 10
# 1.Insert at Beginning
# 2.Insert at Any position
# 3.Insert at End
# 4.Delete at Beginning
# 5.Delete at Any position
# 6.Delete at End
# 7.Display
# 8.Exit
# Enter the choice: 2
# Enter the position: 2
# Enter the data: 8
# 1.Insert at Beginning
# 2.Insert at Any position
# 3.Insert at End
# 4.Delete at Beginning
# 5.Delete at Any position
# 6.Delete at End
# 7.Display
# 8.Exit
# Enter the choice: 7
# 5 --> 10 -->
#
# 1.Insert at Beginning
# 2.Insert at Any position
# 3.Insert at End
# 4.Delete at Beginning
# 5.Delete at Any position
# 6.Delete at End
# 7.Display
# 8.Exit
# ...

# %%
class Node:
    def __init__(self,data):
        self.next=None
        self.data=data
        self.prev=None
class D:
    def __init__(self):
        self.head=None
    def dis(self):
        if self.head is None:
            print("empty")
        else:
            t=self.head
            while t:
                print(f"{t.data}--->",end="")
                t=t.next


    def atb(self,data):
        n=Node(data)
        n.next=self.head
        self.head=n
    def ate(self,data):
        n=Node(data)
        t=self.head
        if t.next!=None:
            t=t.next
        t.next=n
        n.prev=t
    def atm(self,data,pos):
        n=Node(data)
        t=self.head
        for i in range(1,pos-1):
            t=t.next
        n.prev=t
        n.next=t.next
        t.next.prev=n
        t.next=n
    def datb(self):
        if self.head is None:
            print("empty")
        else:
            t=self.head
            self.head=t.next
            del(t)
    def date(self):
        if self.head is None:
            print("empty")
        else:
            temp=self.head.next
            t=self.head
            if temp.next != None:
                temp=temp.next
                t=t.next
            t.next=None
            temp.prev=None
    def datm(self,pos):
        if self.head is None:
            print("empty")
        else:
            temp=self.head.next
            t=self.head
            for i in range(1,pos-1):
                temp=temp.next
                t=t.next
            temp.next=t.next
            temp.prev=None
            temp.next=None

o=D()
while True:
    a=int(input("1\n2\n3\n4\n5\n6\n7\nyour choice"))
    if a==1:
        o.atb(int(input("data")))
    elif a==2:
        o.ate(int(input("data at end")))


    elif a==3:
        o.datb()
    elif a==4:
        o.date()
    elif a==5:
        pos=int(input("postion"))
        data=int(input("data"))
        o.atm(data,pos)
    elif a==6:
        o.datm(int(input("postion to delete")))



    elif a==7:
        o.dis()

    else:
        break
